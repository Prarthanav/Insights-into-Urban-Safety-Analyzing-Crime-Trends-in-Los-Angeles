# %%
#Problem9

import pandas as pd



df = pd.read_csv('Crime_Data_from_2020_to_Present.csv')


print("First few rows of the dataset:")
df.head()
# Out:
# First few rows of the dataset:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1  190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
# 2  200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200     1
# 3  191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730    15
# 4  191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415    19
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Southwest          377         2     624
# 1      Central          163         2     624
# 2      Central          155         2     845
# 3  N Hollywood         1543         2     745
# 4      Mission         1998         2     740
#
#                                          Crm Cd Desc  ... Status  \
# 0                           BATTERY - SIMPLE ASSAULT  ...     AO
# 1                           BATTERY - SIMPLE ASSAULT  ...     IC
# 2          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE  ...     AA
# 3           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
# 4  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
#
#     Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0   Adult Other    624.0      NaN       NaN      NaN
# 1   Invest Cont    624.0      NaN       NaN      NaN
# 2  Adult Arrest    845.0      NaN       NaN      NaN
# 3   Invest Cont    745.0    998.0       NaN      NaN
# 4   Invest Cont    740.0      NaN       NaN      NaN
#
#                                    LOCATION Cross Street      LAT       LON
# 0   1100 W  39TH                         PL          NaN  34.0141 -118.2978
# 1    700 S  HILL                         ST          NaN  34.0459 -118.2545
# 2    200 E  6TH                          ST          NaN  34.0448 -118.2474
# 3   5400    CORTEEN                      PL          NaN  34.1685 -118.4019
# 4  14400    TITUS                        ST          NaN  34.2198 -118.4468
#
# [5 rows x 28 columns]

# %%
top_crime_types = df['Crm Cd Desc'].value_counts().head(10)

print("Top Ten Specific Types of Crimes:")
print(top_crime_types)
# Out:
# Top Ten Specific Types of Crimes:
# VEHICLE - STOLEN                                           88355
# BATTERY - SIMPLE ASSAULT                                   65728
# THEFT OF IDENTITY                                          52136
# BURGLARY FROM VEHICLE                                      50616
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)    50274
# BURGLARY                                                   50228
# ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT             47490
# THEFT PLAIN - PETTY ($950 & UNDER)                         41948
# INTIMATE PARTNER - SIMPLE ASSAULT                          41569
# THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)            31857
# Name: Crm Cd Desc, dtype: int64

# %%
# Visualizing the top ten specific types of crimes

import matplotlib.pyplot as plt



plt.figure(figsize=(10, 6))
top_crime_types.plot(kind='bar', color='skyblue')
plt.title('Top 10 Specific Types of Crimes')
plt.xlabel('Crime Types')
plt.ylabel('Number of Occurrences')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Finding out the count of all genders from the dataset
gender_counts = df['Vict Sex'].value_counts()

# Print out the count of all genders
print("Count of All Genders:")
print(gender_counts)
# Out:
# Count of All Genders:
# M    340664
# F    303878
# X     72050
# H        90
# -         1
# Name: Vict Sex, dtype: int64

# %%
#Visualizing the count of all genders from the dataset

import matplotlib.pyplot as plt



# Find out the count of all genders from the dataset
gender_counts = df['Vict Sex'].value_counts()

# Set the size of the plot
plt.figure(figsize=(8, 6))


plt.bar(gender_counts.index, gender_counts.values, color='skyblue')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Count of All Genders')
plt.xticks(rotation=45)  
plt.tight_layout()
plt.show()

# %%
# Finding out the count of all victim descents from the dataset
victim_descent_counts = df['Vict Descent'].value_counts()

# Print out the count of all victim descents
print("Count of All Victim Descents:")
print(victim_descent_counts)
# Out:
# Count of All Victim Descents:
# H    253152
# W    168138
# B    117571
# X     79573
# O     65408
# A     18056
# K      4391
# F      3435
# C      3167
# J      1145
# V       851
# I       772
# Z       412
# P       219
# U       167
# D        62
# G        58
# L        50
# S        46
# -         2
# Name: Vict Descent, dtype: int64

# %%
# Visualizing the count of all victim descents from the dataset

import matplotlib.pyplot as plt



plt.figure(figsize=(10, 6))


victim_descent_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Victim Descent')
plt.ylabel('Count')
plt.title('Count of Victim Descents')
plt.xticks(rotation=45)  
plt.tight_layout()
plt.show()

# %%
#Visualizing the relationship between AGE and TEN MOST SPECIFIC CRIMES

import seaborn as sns
import matplotlib.pyplot as plt


top_crimes = ['VEHICLE - STOLEN', 'BATTERY - SIMPLE ASSAULT', 'THEFT OF IDENTITY', 
              'BURGLARY FROM VEHICLE', 'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)',
              'BURGLARY', 'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT', 
              'THEFT PLAIN - PETTY ($950 & UNDER)', 'INTIMATE PARTNER - SIMPLE ASSAULT',
              'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)']

filtered_df = df[df['Crm Cd Desc'].isin(top_crimes)]

# Set the size of the plot
plt.figure(figsize=(12, 8))

sns.violinplot(x='Crm Cd Desc', y='Vict Age', data=filtered_df, order=top_crimes, palette='muted', inner='quartile')
plt.xticks(rotation=45, ha='right')  
plt.title('Relationship between Specific Types of Crimes and Age')
plt.xlabel('Specific Type of Crime')
plt.ylabel('Age')
plt.tight_layout()
plt.show()

# %%
#Visualizing the relationship between GENDER and TEN MOST SPECIFIC CRIMES

import matplotlib.pyplot as plt


top_crimes = ['VEHICLE - STOLEN', 'BATTERY - SIMPLE ASSAULT', 'THEFT OF IDENTITY', 
              'BURGLARY FROM VEHICLE', 'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)',
              'BURGLARY', 'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT', 
              'THEFT PLAIN - PETTY ($950 & UNDER)', 'INTIMATE PARTNER - SIMPLE ASSAULT',
              'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)']

filtered_df = df[df['Crm Cd Desc'].isin(top_crimes)]


gender_counts = filtered_df.groupby(['Crm Cd Desc', 'Vict Sex'])['Crm Cd Desc'].count().unstack().fillna(0)


plt.figure(figsize=(20, 14))  


ax = gender_counts.plot(kind='bar', stacked=True, colormap='viridis')
plt.xticks(rotation=45, ha='right', fontsize=8)  # Rotate x-axis labels and reduce font size
plt.title('Relationship between Specific Types of Crimes and Gender', fontsize=14)
plt.xlabel('Specific Type of Crime', fontsize=5)
plt.ylabel('Count ', fontsize=12)


plt.legend(title='Gender', bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=5)

plt.tight_layout()
plt.show()

# %%
import pandas as pd



filtered_df = df[df['Vict Descent'].isin(['H', 'W', 'B', 'X'])]
filtered_df = filtered_df[filtered_df['Crm Cd Desc'].isin(['VEHICLE - STOLEN', 'BATTERY - SIMPLE ASSAULT',
                                                           'THEFT OF IDENTITY', 'BURGLARY FROM VEHICLE',
                                                           'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)',
                                                           'BURGLARY', 'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
                                                           'THEFT PLAIN - PETTY ($950 & UNDER)',
                                                           'INTIMATE PARTNER - SIMPLE ASSAULT',
                                                           'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)'])]


crime_by_descent = pd.crosstab(filtered_df['Crm Cd Desc'], filtered_df['Vict Descent'])

# Print the cross-tabulation
print(crime_by_descent)
# Out:
# Vict Descent                                            B      H      W      X
# Crm Cd Desc
# ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT      12878  23543   6527   1304
# BATTERY - SIMPLE ASSAULT                            12952  32828  12221    613
# BURGLARY                                             4356   7617  15560  12431
# BURGLARY FROM VEHICLE                                7311  15430  16285   1345
# INTIMATE PARTNER - SIMPLE ASSAULT                   10159  21922   6391    151
# THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)      1700   5418   4629    502
# THEFT OF IDENTITY                                   12014  17172  14391    810
# THEFT PLAIN - PETTY ($950 & UNDER)                   6007  10158  12974   4622
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VAN...   6642  15174  10915  10230
# VEHICLE - STOLEN                                       52    173     63    126

# %%
#Visualizing the relationship between 4 DESCENTs with the most people and TEN MOST SPECIFIC CRIMES

import matplotlib.pyplot as plt



# Set the size of the plot
plt.figure(figsize=(16, 10))  


crime_by_descent.plot(kind='bar', stacked=True, colormap='viridis')
plt.xlabel('Specific Type of Crime')
plt.ylabel('Count')
plt.title('Relationship between Victim Descent and Specific Types of Crimes')
plt.xticks(rotation=45, ha='right', fontsize=5)  


plt.legend(title='Victim Descent', bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)

plt.tight_layout()
plt.show()

# %%
#Problem10
crime_count = df.groupby(pd.to_datetime(df['DATE OCC']).dt.to_period('M')).size().reset_index(name='Crime Count')

# Set 'DATE OCC' as the index
crime_count.set_index('DATE OCC', inplace=True)
# Plot Historical Crime Data (monthly)
plt.plot(crime_count.index.to_timestamp(), crime_count['Crime Count'], label='Historical Crime Data', marker='o')
plt.xlabel('Date (Monthly)')
plt.ylabel('Crime Count')
# Out:
# Text(0, 0.5, 'Crime Count')

# %%
from statsmodels.tsa.arima.model import ARIMA

crime_count = df.groupby(pd.to_datetime(df['DATE OCC']).dt.to_period('M')).size().reset_index(name='Crime Count')

# Set 'DATE OCC' as the index
crime_count.set_index('DATE OCC', inplace=True)

# ARIMA Model
arima_model = ARIMA(crime_count['Crime Count'], order=(5,1,0))  # Example order, tune this based on your data
arima_result = arima_model.fit()
arima_forecast = arima_result.predict(start=len(crime_count), end=len(crime_count) + 11, typ='levels')  # Forecast 1 year ahead

# Plot ARIMA Forecast (monthly)
forecast_index = pd.date_range(start=crime_count.index[-1].to_timestamp(), periods=12, freq='M')
plt.plot(forecast_index, arima_forecast, label='ARIMA Forecast', color='orange', marker='o')

plt.xlabel('Date (Monthly)')
plt.ylabel('Crime Count')
plt.title('Historical Crime Data and ARIMA Forecast')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning: Unknown keyword arguments: dict_keys(['typ']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
#   warnings.warn(msg, FutureWarning)
